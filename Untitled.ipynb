# %%
import json
import pandas as pd
# pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', None)
data = json.load(open('drug-label-0009-of-0009.json'))
df = pd.DataFrame(data["results"])

# %%
df.head(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            package_label_principal_display_panel  \
# 0  [DRUG: Miconazole Nitrate GENERIC: Miconazole Nitrate DOSAGE: CREAM ADMINSTRATION: VAGINAL NDC: 70518-0811-0 PACKAGING: 45 g in 1 TUBE, WITH APPLICATOR ACTIVE INGREDIENT(S): Miconazole Nitrate 20mg in 1g INACTIVE INGREDIENT(S): Benzoic Acid Peg-5 Oleate Pegoxol 7 Stearate Butylated Hydroxyanisole Mineral Oil Water Remedy_Label]
# ...

# %%
df.isna().sum().tolist()
# Out:
# [0,
#  368,
#  255,
#  143,
#  255,
#  0,
#  0,
#  257,
#  0,
#  0,
#  6,
#  0,
#  255,
#  430,
#  0,
#  4,
#  464,
#  317,
#  387,
#  353,
#  414,
#  483,
#  561,
#  518,
#  569,
#  382,
#  359,
#  415,
#  452,
#  362,
#  355,
#  559,
#  519,
#  319,
#  303,
#  372,
#  493,
#  318,
#  478,
#  322,
#  435,
#  321,
#  473,
#  316,
#  418,
#  535,
#  442,
#  433,
#  385,
#  422,
#  439,
#  445,
#  437,
#  517,
#  501,
#  469,
#  518,
#  454,
#  521,
#  471,
#  476,
#  554,
#  518,
#  563,
#  509,
#  571,
#  543,
#  543,
#  538,
#  557,
#  543,
#  541,
#  543,
#  539,
#  552,
#  569,
#  571,
#  567,
#  548,
#  566,
#  561,
#  550,
#  571,
#  568,
#  520,
#  568,
#  565,
#  570,
#  568,
#  571,
#  571,
#  571,
#  568,
#  572,
#  569,
#  571,
#  572,
#  569,
#  572,
#  570,
#  571,
#  571,
#  572,
#  572,
#  572,
#  572,
#  572,
#  572]

# %%
val = df["active_ingredient"][0]

# %%
def list_to_str(text):
    return ' '.join([str(elem) for elem in text])

# %%
# df["package_label_principal_display_panel"] = df["package_label_principal_display_panel"].apply(list_to_str)
# df["storage_and_handling"] = df["storage_and_handling"].apply(list_to_str)
# df["active_ingredient"] = df["active_ingredient"].apply(list_to_str)
# df["warnings"] = df["warnings"].apply(list_to_str)
# df["package_label_principal_display_panel"] = df["package_label_principal_display_panel"].apply(list_to_str)

# %%
df.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            package_label_principal_display_panel  \
# 0  [DRUG: Miconazole Nitrate GENERIC: Miconazole Nitrate DOSAGE: CREAM ADMINSTRATION: VAGINAL NDC: 70518-0811-0 PACKAGING: 45 g in 1 TUBE, WITH APPLICATOR ACTIVE INGREDIENT(S): Miconazole Nitrate 20mg in 1g INACTIVE INGREDIENT(S): Benzoic Acid Peg-5 Oleate Pegoxol 7 Stearate Butylated Hydroxyanisole Mineral Oil Water Remedy_Label]
# ...

# %%
print(' '.join([str(elem) for elem in val]))
# Out:
# ACTIVE INGREDIENT Miconazole nitrate 2% (100 mg in each applicator) Miconazole nitrate 2% (as external cream)

# %%
df.shape
# Out:
# (573, 108)

# %%
df.columns.to_list()
# Out:
# ['package_label_principal_display_panel',
#  'storage_and_handling',
#  'active_ingredient',
#  'warnings',
#  'inactive_ingredient',
#  'effective_time',
#  'openfda',
#  'keep_out_of_reach_of_children',
#  'spl_product_data_elements',
#  'set_id',
#  'dosage_and_administration',
#  'version',
#  'purpose',
#  'questions',
#  'id',
#  'indications_and_usage',
#  'pregnancy_or_breast_feeding',
#  'spl_unclassified_section',
#  'do_not_use',
#  'stop_use',
#  'when_using',
#  'recent_major_changes',
#  'instructions_for_use',
#  'laboratory_tests',
#  'pharmacodynamics_table',
#  'carcinogenesis_and_mutagenesis_and_impairment_of_fertility',
#  'pregnancy',
#  'pharmacokinetics',
#  'precautions',
#  'drug_interactions',
#  'pediatric_use',
#  'nonteratogenic_effects',
#  'spl_patient_package_insert',
#  'contraindications',
#  'adverse_reactions',
#  'information_for_patients',
#  'general_precautions',
#  'description',
#  'clinical_pharmacology_table',
#  'clinical_pharmacology',
# ...

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df
# Out:
#                                                                                                                        column_name  \
# package_label_principal_display_panel                             package_label_principal_display_panel
# storage_and_handling                                              storage_and_handling
# active_ingredient                                                 active_ingredient
# warnings                                                          warnings
# inactive_ingredient                                               inactive_ingredient
# effective_time                                                    effective_time
# openfda                                                           openfda
# keep_out_of_reach_of_children                                     keep_out_of_reach_of_children
# spl_product_data_elements                                         spl_product_data_elements
# ...

# %%
# df = pd.read_json("drug-label-0001-of-0009.json")
# df.to_csv("drug_big.csv")

# %%
import vaex

# %%
vaex_df = vaex.from_csv("drug-label-0001-of-0009.json", convert=True, chunk_size=5_000_000)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-44-5f268f453600> in <module>
# ----> 1 vaex_df = vaex.from_csv("drug-label-0001-of-0009.json", convert=True, chunk_size=5_000_000)
#
# ~/.local/lib/python3.6/site-packages/vaex/__init__.py in from_csv(filename_or_buffer, copy_index, chunk_size, convert, **kwargs)
#     499             chunk_size = 5_000_000
#     500         return _from_csv_convert_and_read(filename_or_buffer=filename_or_buffer, copy_index=copy_index,
# --> 501                                           maybe_convert_path=convert, chunk_size=chunk_size, **kwargs)
#     502
#     503
#
# ~/.local/lib/python3.6/site-packages/vaex/__init__.py in _from_csv_convert_and_read(filename_or_buffer, copy_index, maybe_convert_path, chunk_size, **kwargs)
#     535     converted_paths = []
# ...
